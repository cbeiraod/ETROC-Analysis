# %% [markdown]
# # S-Curve Scan with Qinj

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1 import make_axes_locatable
import os
from fnmatch import fnmatch
import hist
from hist import Hist
import scipy.stats as stats

# %%
QInjEns = [5, 6, 10, 15, 20, 25, 30]
thresholds = {5:np.arange(232,285,2),
              6:np.arange(232,285,2),
              10:np.arange(232,320,2),
              15:np.arange(232,360,2),
              20:np.arange(232,410,2),
              25:np.arange(232,455,2),
              30:np.arange(232,495,2)
}
row_list = [3]
col_list = [3]
scan_list = list(zip(col_list, row_list))
print(scan_list)
# Out:
# [(3, 3)]

# %%
def return_empty_list():
    return {(row,col):{q:{DAC:0 for DAC in thresholds[q]}for q in QInjEns}for row,col in scan_list}

# %%
h = {(row,col):{q:{DAC:(
        Hist.new.Integer(125, 165, name="CAL", label="CAL [LSB]")
        .Integer(45, 85, name="TOT", label="TOT [LSB]")
        .Integer(150, 275, name="TOA", label="TOA [LSB]")
        .Double()
      )
      for DAC in thresholds[q]}
     for q in QInjEns}
    for row,col in scan_list}
hit_counts = return_empty_list()
CAL_sum = return_empty_list()
CAL_sum_sq = return_empty_list()
TOA_sum = return_empty_list()
TOA_sum_sq = return_empty_list()
TOT_sum = return_empty_list()
TOT_sum_sq = return_empty_list()
toa_30fc = []
tot_30fc = []
cal_30fc = []

# %%
root = '../ETROC-Data'
file_pattern = "*translated*.dat"
for index, row, col in zip((range(len(row_list))), row_list, col_list):
    for QInj in (QInjEns):
        for idx_DAC,DAC in enumerate(thresholds[QInj]):
            print(f'Pixel {col},{row} - {QInj} fC - DAC {DAC}')
            path_pattern = f"*2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C{col}_R{row}_QInj_{QInj}_Threshold_{DAC}"
            file_list = []
            for path, subdirs, files in os.walk(root):
                if not fnmatch(path, path_pattern): continue
                for name in files:
                    pass
                    if fnmatch(name, file_pattern):
                        file_list.append(os.path.join(path, name))
                        print(file_list[-1])
            current_bcid = -1
            previous_bcid = -1
            total_files = len(file_list)
            for file_index, file_name in enumerate(file_list):
                print(f"{file_index+1}/{total_files}")
                with open(file_name) as infile:
                    for line in infile:
                        text_list = line.split()
                        if(text_list[2]=="HEADER"): current_bcid = int(text_list[8])
                        elif(text_list[2]=="TRAILER"): previous_bcid = current_bcid
                        if(previous_bcid==-1 or (current_bcid-previous_bcid==68 if current_bcid>=previous_bcid else current_bcid+3564-previous_bcid==68)): continue
                        # if((current_bcid-previous_bcid!=1054 if current_bcid>=previous_bcid else current_bcid+3564-previous_bcid!=1054)): continue
                        if text_list[2]!="DATA": continue
                        c_running = int(text_list[6])
                        r_running = int(text_list[8])
                        if(c_running!=col or r_running!=row): continue
                        TOA = int(text_list[10])
                        TOT = int(text_list[12])
                        CAL = int(text_list[14])
                        if(CAL>200 or CAL<100): continue
                        CAL_sum[(r_running,c_running)][QInj][DAC] += CAL
                        CAL_sum_sq[(r_running,c_running)][QInj][DAC] += CAL*CAL
                        TOA_sum[(r_running,c_running)][QInj][DAC] += TOA
                        TOA_sum_sq[(r_running,c_running)][QInj][DAC] += TOA*TOA
                        TOT_sum[(r_running,c_running)][QInj][DAC] += TOT
                        TOT_sum_sq[(r_running,c_running)][QInj][DAC] += TOT*TOT
                        h[(r_running,c_running)][QInj][DAC].fill(CAL,TOT,TOA)
                        hit_counts[(r_running,c_running)][QInj][DAC] += 1 
                        if(QInj==30 and idx_DAC>=16):
                            toa_30fc.append(TOA)
                            tot_30fc.append(TOT)
                            cal_30fc.append(CAL)
# Out:
# Pixel 3,3 - 5 fC - DAC 232
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_232/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 234
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_234/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 236
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_236/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 238
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_238/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 240
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_240/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 242
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_242/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 244
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_244/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 246
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_246/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 248
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_248/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 250
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_250/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 252
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_252/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 254
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_254/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 256
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_256/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 258
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_258/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 260
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_260/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 262
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_262/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 264
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_264/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 266
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_266/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 268
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_268/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 270
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_270/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 272
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_272/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 274
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_274/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 276
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_276/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 278
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_278/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 280
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_280/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 282
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_282/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 5 fC - DAC 284
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_5_Threshold_284/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 232
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_232/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 234
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_234/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 236
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_236/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 238
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_238/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 240
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_240/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 242
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_242/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 244
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_244/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 246
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_246/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 248
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_248/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 250
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_250/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 252
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_252/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 254
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_254/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 256
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_256/TDC_Data_translated_1.dat
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_256/TDC_Data_translated_0.dat
# 1/2
# 2/2
# Pixel 3,3 - 6 fC - DAC 258
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_258/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 260
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_260/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 262
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_262/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 264
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_264/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 266
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_266/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 268
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_268/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 270
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_270/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 272
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_272/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 274
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_274/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 276
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_276/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 278
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_278/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 280
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_280/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 282
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_282/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 6 fC - DAC 284
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_6_Threshold_284/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 232
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_232/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 234
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_234/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 236
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_236/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 238
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_238/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 240
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_240/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 242
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_242/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 244
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_244/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 246
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_246/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 248
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_248/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 250
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_250/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 252
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_252/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 254
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_254/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 256
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_256/TDC_Data_translated_1.dat
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_256/TDC_Data_translated_0.dat
# 1/2
# 2/2
# Pixel 3,3 - 10 fC - DAC 258
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_258/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 260
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_260/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 262
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_262/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 264
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_264/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 266
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_266/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 268
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_268/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 270
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_270/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 272
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_272/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 274
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_274/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 276
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_276/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 278
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_278/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 280
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_280/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 282
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_282/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 284
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_284/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 286
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_286/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 288
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_288/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 290
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_290/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 292
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_292/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 294
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_294/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 296
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_296/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 298
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_298/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 300
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_300/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 302
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_302/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 304
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_304/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 306
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_306/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 308
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_308/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 310
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_310/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 312
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_312/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 314
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_314/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 316
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_316/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 10 fC - DAC 318
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_10_Threshold_318/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 232
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_232/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 234
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_234/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 236
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_236/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 238
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_238/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 240
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_240/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 242
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_242/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 244
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_244/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 246
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_246/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 248
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_248/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 250
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_250/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 252
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_252/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 254
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_254/TDC_Data_translated_1.dat
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_254/TDC_Data_translated_0.dat
# 1/2
# 2/2
# Pixel 3,3 - 15 fC - DAC 256
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_256/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 258
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_258/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 260
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_260/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 262
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_262/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 264
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_264/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 266
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_266/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 268
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_268/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 270
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_270/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 272
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_272/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 274
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_274/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 276
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_276/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 278
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_278/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 280
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_280/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 282
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_282/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 284
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_284/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 286
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_286/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 288
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_288/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 290
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_290/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 292
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_292/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 294
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_294/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 296
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_296/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 298
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_298/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 300
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_300/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 302
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_302/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 304
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_304/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 306
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_306/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 308
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_308/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 310
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_310/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 312
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_312/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 314
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_314/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 316
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_316/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 318
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_318/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 320
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_320/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 322
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_322/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 324
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_324/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 326
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_326/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 328
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_328/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 330
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_330/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 332
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_332/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 334
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_334/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 336
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_336/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 338
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_338/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 340
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_340/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 342
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_342/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 344
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_344/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 346
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_346/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 348
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_348/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 350
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_350/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 352
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_352/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 354
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_354/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 356
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_356/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 15 fC - DAC 358
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_15_Threshold_358/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 232
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_232/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 234
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_234/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 236
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_236/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 238
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_238/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 240
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_240/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 242
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_242/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 244
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_244/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 246
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_246/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 248
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_248/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 250
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_250/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 252
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_252/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 254
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_254/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 256
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_256/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 258
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_258/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 260
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_260/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 262
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_262/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 264
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_264/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 266
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_266/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 268
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_268/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 270
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_270/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 272
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_272/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 274
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_274/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 276
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_276/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 278
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_278/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 280
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_280/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 282
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_282/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 284
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_284/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 286
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_286/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 288
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_288/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 290
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_290/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 292
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_292/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 294
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_294/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 296
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_296/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 298
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_298/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 300
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_300/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 302
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_302/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 304
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_304/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 306
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_306/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 308
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_308/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 310
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_310/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 312
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_312/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 314
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_314/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 316
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_316/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 318
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_318/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 320
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_320/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 322
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_322/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 324
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_324/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 326
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_326/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 328
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_328/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 330
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_330/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 332
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_332/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 334
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_334/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 336
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_336/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 338
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_338/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 340
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_340/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 342
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_342/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 344
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_344/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 346
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_346/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 348
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_348/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 350
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_350/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 352
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_352/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 354
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_354/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 356
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_356/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 358
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_358/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 360
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_360/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 362
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_362/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 364
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_364/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 366
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_366/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 368
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_368/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 370
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_370/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 372
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_372/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 374
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_374/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 376
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_376/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 378
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_378/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 380
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_380/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 382
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_382/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 384
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_384/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 386
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_386/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 388
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_388/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 390
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_390/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 392
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_392/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 394
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_394/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 396
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_396/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 398
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_398/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 400
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_400/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 402
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_402/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 404
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_404/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 406
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_406/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 20 fC - DAC 408
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_20_Threshold_408/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 232
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_232/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 234
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_234/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 236
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_236/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 238
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_238/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 240
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_240/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 242
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_242/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 244
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_244/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 246
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_246/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 248
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_248/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 250
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_250/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 252
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_252/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 254
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_254/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 256
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_256/TDC_Data_translated_2.dat
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_256/TDC_Data_translated_1.dat
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_256/TDC_Data_translated_0.dat
# 1/3
# 2/3
# 3/3
# Pixel 3,3 - 25 fC - DAC 258
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_258/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 260
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_260/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 262
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_262/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 264
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_264/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 266
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_266/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 268
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_268/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 270
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_270/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 272
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_272/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 274
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_274/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 276
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_276/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 278
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_278/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 280
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_280/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 282
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_282/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 284
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_284/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 286
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_286/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 288
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_288/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 290
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_290/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 292
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_292/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 294
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_294/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 296
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_296/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 298
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_298/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 300
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_300/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 302
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_302/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 304
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_304/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 306
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_306/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 308
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_308/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 310
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_310/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 312
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_312/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 314
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_314/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 316
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_316/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 318
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_318/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 320
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_320/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 322
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_322/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 324
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_25_Threshold_324/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 25 fC - DAC 326
# ...
# 1/1
# Pixel 3,3 - 30 fC - DAC 296
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_296/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 298
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_298/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 300
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_300/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 302
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_302/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 304
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_304/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 306
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_306/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 308
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_308/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 310
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_310/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 312
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_312/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 314
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_314/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 316
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_316/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 318
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_318/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 320
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_320/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 322
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_322/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 324
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_324/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 326
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_326/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 328
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_328/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 330
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_330/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 332
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_332/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 334
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_334/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 336
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_336/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 338
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_338/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 340
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_340/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 342
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_342/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 344
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_344/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 346
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_346/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 348
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_348/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 350
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_350/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 352
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_352/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 354
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_354/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 356
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_356/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 358
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_358/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 360
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_360/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 362
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_362/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 364
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_364/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 366
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_366/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 368
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_368/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 370
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_370/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 372
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_372/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 374
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_374/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 376
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_376/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 378
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_378/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 380
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_380/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 382
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_382/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 384
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_384/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 386
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_386/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 388
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_388/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 390
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_390/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 392
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_392/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 394
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_394/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 396
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_396/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 398
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_398/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 400
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_400/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 402
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_402/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 404
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_404/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 406
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_406/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 408
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_408/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 410
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_410/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 412
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_412/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 414
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_414/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 416
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_416/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 418
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_418/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 420
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_420/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 422
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_422/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 424
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_424/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 426
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_426/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 428
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_428/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 430
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_430/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 432
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_432/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 434
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_434/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 436
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_436/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 438
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_438/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 440
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_440/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 442
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_442/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 444
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_444/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 446
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_446/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 448
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_448/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 450
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_450/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 452
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_452/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 454
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_454/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 456
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_456/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 458
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_458/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 460
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_460/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 462
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_462/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 464
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_464/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 466
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_466/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 468
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_468/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 470
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_470/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 472
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_472/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 474
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_474/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 476
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_476/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 478
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_478/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 480
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_480/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 482
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_482/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 484
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_484/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 486
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_486/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 488
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_488/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 490
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_490/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 492
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_492/TDC_Data_translated_0.dat
# 1/1
# Pixel 3,3 - 30 fC - DAC 494
# ../ETROC-Data/2023-06-10_Array_Test_Results/E2_testing_VRef_SCurve_Pixel_C3_R3_QInj_30_Threshold_494/TDC_Data_translated_0.dat
# 1/1

# %%
toa_30fc = np.array(toa_30fc)
tot_30fc = np.array(tot_30fc)

# %%
CAL_mean = return_empty_list()
CAL_std = return_empty_list()
TOA_mean = return_empty_list()
TOA_std = return_empty_list()
TOT_mean = return_empty_list()
TOT_std = return_empty_list()
for index, row, col in zip((range(len(row_list))), row_list, col_list):
    for QInj in (QInjEns):
        for DAC in (thresholds[QInj]):
            if(hit_counts[(row,col)][QInj][DAC]==0): 
                CAL_mean[(row,col)][QInj][DAC] = np.nan
                CAL_std[(row,col)][QInj][DAC] = np.nan
                TOA_std[(row,col)][QInj][DAC] = np.nan
                TOT_mean[(row,col)][QInj][DAC] = np.nan
                TOT_std[(row,col)][QInj][DAC] = np.nan
                continue
            CAL_mean[(row,col)][QInj][DAC] = CAL_sum[(row,col)][QInj][DAC]/hit_counts[(row,col)][QInj][DAC]
            CAL_std[(row,col)][QInj][DAC] = np.sqrt((CAL_sum_sq[(row,col)][QInj][DAC]/hit_counts[(row,col)][QInj][DAC]) - pow(CAL_mean[(row,col)][QInj][DAC], 2))
            TOA_mean[(row,col)][QInj][DAC] = TOA_sum[(row,col)][QInj][DAC]/hit_counts[(row,col)][QInj][DAC]
            TOA_std[(row,col)][QInj][DAC] = np.sqrt((TOA_sum_sq[(row,col)][QInj][DAC]/hit_counts[(row,col)][QInj][DAC]) - pow(TOA_mean[(row,col)][QInj][DAC], 2))
            TOT_mean[(row,col)][QInj][DAC] = TOT_sum[(row,col)][QInj][DAC]/hit_counts[(row,col)][QInj][DAC]
            TOT_std[(row,col)][QInj][DAC] = np.sqrt((TOT_sum_sq[(row,col)][QInj][DAC]/hit_counts[(row,col)][QInj][DAC]) - pow(TOT_mean[(row,col)][QInj][DAC], 2))

# %%
BL_map_THCal = return_empty_list()
NW_map_THCal = return_empty_list()
root = '../ETROC-Data'
path = '/2023-06-10_Array_Test_Results/thresholds_npys/'
for index, row, col in zip((range(len(row_list))), row_list, col_list):
    for QInj in (QInjEns):
        for DAC in (thresholds[QInj]):
            print(f'Pixel {col},{row} - {QInj} fC - DAC {DAC}')
            file_pattern = f"2023-06-10_Array_Test_ResultsE2_testing_VRef_SCurve_Pixel_C{col}_R{row}_QInj_{QInj}_Threshold_{DAC}"
            BL_map_THCal[(row,col)][QInj][DAC] = np.load(root+path+file_pattern+"_BL.npy")
            NW_map_THCal[(row,col)][QInj][DAC] = np.load(root+path+file_pattern+"_NW.npy")
# Out:
# Pixel 3,3 - 5 fC - DAC 232
# Pixel 3,3 - 5 fC - DAC 234
# Pixel 3,3 - 5 fC - DAC 236
# Pixel 3,3 - 5 fC - DAC 238
# Pixel 3,3 - 5 fC - DAC 240
# Pixel 3,3 - 5 fC - DAC 242
# Pixel 3,3 - 5 fC - DAC 244
# Pixel 3,3 - 5 fC - DAC 246
# Pixel 3,3 - 5 fC - DAC 248
# Pixel 3,3 - 5 fC - DAC 250
# Pixel 3,3 - 5 fC - DAC 252
# Pixel 3,3 - 5 fC - DAC 254
# Pixel 3,3 - 5 fC - DAC 256
# Pixel 3,3 - 5 fC - DAC 258
# Pixel 3,3 - 5 fC - DAC 260
# Pixel 3,3 - 5 fC - DAC 262
# Pixel 3,3 - 5 fC - DAC 264
# Pixel 3,3 - 5 fC - DAC 266
# Pixel 3,3 - 5 fC - DAC 268
# Pixel 3,3 - 5 fC - DAC 270
# Pixel 3,3 - 5 fC - DAC 272
# Pixel 3,3 - 5 fC - DAC 274
# Pixel 3,3 - 5 fC - DAC 276
# Pixel 3,3 - 5 fC - DAC 278
# Pixel 3,3 - 5 fC - DAC 280
# Pixel 3,3 - 5 fC - DAC 282
# Pixel 3,3 - 5 fC - DAC 284
# Pixel 3,3 - 6 fC - DAC 232
# Pixel 3,3 - 6 fC - DAC 234
# Pixel 3,3 - 6 fC - DAC 236
# Pixel 3,3 - 6 fC - DAC 238
# Pixel 3,3 - 6 fC - DAC 240
# Pixel 3,3 - 6 fC - DAC 242
# Pixel 3,3 - 6 fC - DAC 244
# Pixel 3,3 - 6 fC - DAC 246
# Pixel 3,3 - 6 fC - DAC 248
# Pixel 3,3 - 6 fC - DAC 250
# Pixel 3,3 - 6 fC - DAC 252
# Pixel 3,3 - 6 fC - DAC 254
# Pixel 3,3 - 6 fC - DAC 256
# Pixel 3,3 - 6 fC - DAC 258
# Pixel 3,3 - 6 fC - DAC 260
# Pixel 3,3 - 6 fC - DAC 262
# Pixel 3,3 - 6 fC - DAC 264
# Pixel 3,3 - 6 fC - DAC 266
# Pixel 3,3 - 6 fC - DAC 268
# Pixel 3,3 - 6 fC - DAC 270
# Pixel 3,3 - 6 fC - DAC 272
# Pixel 3,3 - 6 fC - DAC 274
# Pixel 3,3 - 6 fC - DAC 276
# Pixel 3,3 - 6 fC - DAC 278
# Pixel 3,3 - 6 fC - DAC 280
# Pixel 3,3 - 6 fC - DAC 282
# Pixel 3,3 - 6 fC - DAC 284
# Pixel 3,3 - 10 fC - DAC 232
# Pixel 3,3 - 10 fC - DAC 234
# Pixel 3,3 - 10 fC - DAC 236
# Pixel 3,3 - 10 fC - DAC 238
# Pixel 3,3 - 10 fC - DAC 240
# Pixel 3,3 - 10 fC - DAC 242
# Pixel 3,3 - 10 fC - DAC 244
# Pixel 3,3 - 10 fC - DAC 246
# Pixel 3,3 - 10 fC - DAC 248
# Pixel 3,3 - 10 fC - DAC 250
# Pixel 3,3 - 10 fC - DAC 252
# Pixel 3,3 - 10 fC - DAC 254
# Pixel 3,3 - 10 fC - DAC 256
# Pixel 3,3 - 10 fC - DAC 258
# Pixel 3,3 - 10 fC - DAC 260
# Pixel 3,3 - 10 fC - DAC 262
# Pixel 3,3 - 10 fC - DAC 264
# Pixel 3,3 - 10 fC - DAC 266
# Pixel 3,3 - 10 fC - DAC 268
# Pixel 3,3 - 10 fC - DAC 270
# Pixel 3,3 - 10 fC - DAC 272
# Pixel 3,3 - 10 fC - DAC 274
# Pixel 3,3 - 10 fC - DAC 276
# Pixel 3,3 - 10 fC - DAC 278
# Pixel 3,3 - 10 fC - DAC 280
# Pixel 3,3 - 10 fC - DAC 282
# Pixel 3,3 - 10 fC - DAC 284
# Pixel 3,3 - 10 fC - DAC 286
# Pixel 3,3 - 10 fC - DAC 288
# Pixel 3,3 - 10 fC - DAC 290
# Pixel 3,3 - 10 fC - DAC 292
# Pixel 3,3 - 10 fC - DAC 294
# Pixel 3,3 - 10 fC - DAC 296
# Pixel 3,3 - 10 fC - DAC 298
# Pixel 3,3 - 10 fC - DAC 300
# Pixel 3,3 - 10 fC - DAC 302
# Pixel 3,3 - 10 fC - DAC 304
# Pixel 3,3 - 10 fC - DAC 306
# Pixel 3,3 - 10 fC - DAC 308
# Pixel 3,3 - 10 fC - DAC 310
# Pixel 3,3 - 10 fC - DAC 312
# Pixel 3,3 - 10 fC - DAC 314
# Pixel 3,3 - 10 fC - DAC 316
# Pixel 3,3 - 10 fC - DAC 318
# Pixel 3,3 - 15 fC - DAC 232
# Pixel 3,3 - 15 fC - DAC 234
# Pixel 3,3 - 15 fC - DAC 236
# Pixel 3,3 - 15 fC - DAC 238
# Pixel 3,3 - 15 fC - DAC 240
# Pixel 3,3 - 15 fC - DAC 242
# Pixel 3,3 - 15 fC - DAC 244
# Pixel 3,3 - 15 fC - DAC 246
# Pixel 3,3 - 15 fC - DAC 248
# Pixel 3,3 - 15 fC - DAC 250
# Pixel 3,3 - 15 fC - DAC 252
# Pixel 3,3 - 15 fC - DAC 254
# Pixel 3,3 - 15 fC - DAC 256
# Pixel 3,3 - 15 fC - DAC 258
# Pixel 3,3 - 15 fC - DAC 260
# Pixel 3,3 - 15 fC - DAC 262
# Pixel 3,3 - 15 fC - DAC 264
# Pixel 3,3 - 15 fC - DAC 266
# Pixel 3,3 - 15 fC - DAC 268
# Pixel 3,3 - 15 fC - DAC 270
# Pixel 3,3 - 15 fC - DAC 272
# Pixel 3,3 - 15 fC - DAC 274
# Pixel 3,3 - 15 fC - DAC 276
# Pixel 3,3 - 15 fC - DAC 278
# Pixel 3,3 - 15 fC - DAC 280
# Pixel 3,3 - 15 fC - DAC 282
# Pixel 3,3 - 15 fC - DAC 284
# Pixel 3,3 - 15 fC - DAC 286
# Pixel 3,3 - 15 fC - DAC 288
# Pixel 3,3 - 15 fC - DAC 290
# Pixel 3,3 - 15 fC - DAC 292
# Pixel 3,3 - 15 fC - DAC 294
# Pixel 3,3 - 15 fC - DAC 296
# Pixel 3,3 - 15 fC - DAC 298
# Pixel 3,3 - 15 fC - DAC 300
# Pixel 3,3 - 15 fC - DAC 302
# Pixel 3,3 - 15 fC - DAC 304
# Pixel 3,3 - 15 fC - DAC 306
# Pixel 3,3 - 15 fC - DAC 308
# Pixel 3,3 - 15 fC - DAC 310
# Pixel 3,3 - 15 fC - DAC 312
# Pixel 3,3 - 15 fC - DAC 314
# Pixel 3,3 - 15 fC - DAC 316
# Pixel 3,3 - 15 fC - DAC 318
# Pixel 3,3 - 15 fC - DAC 320
# Pixel 3,3 - 15 fC - DAC 322
# Pixel 3,3 - 15 fC - DAC 324
# Pixel 3,3 - 15 fC - DAC 326
# Pixel 3,3 - 15 fC - DAC 328
# Pixel 3,3 - 15 fC - DAC 330
# Pixel 3,3 - 15 fC - DAC 332
# Pixel 3,3 - 15 fC - DAC 334
# Pixel 3,3 - 15 fC - DAC 336
# Pixel 3,3 - 15 fC - DAC 338
# Pixel 3,3 - 15 fC - DAC 340
# Pixel 3,3 - 15 fC - DAC 342
# Pixel 3,3 - 15 fC - DAC 344
# Pixel 3,3 - 15 fC - DAC 346
# Pixel 3,3 - 15 fC - DAC 348
# Pixel 3,3 - 15 fC - DAC 350
# Pixel 3,3 - 15 fC - DAC 352
# Pixel 3,3 - 15 fC - DAC 354
# Pixel 3,3 - 15 fC - DAC 356
# Pixel 3,3 - 15 fC - DAC 358
# Pixel 3,3 - 20 fC - DAC 232
# Pixel 3,3 - 20 fC - DAC 234
# Pixel 3,3 - 20 fC - DAC 236
# Pixel 3,3 - 20 fC - DAC 238
# Pixel 3,3 - 20 fC - DAC 240
# Pixel 3,3 - 20 fC - DAC 242
# Pixel 3,3 - 20 fC - DAC 244
# Pixel 3,3 - 20 fC - DAC 246
# Pixel 3,3 - 20 fC - DAC 248
# Pixel 3,3 - 20 fC - DAC 250
# Pixel 3,3 - 20 fC - DAC 252
# Pixel 3,3 - 20 fC - DAC 254
# Pixel 3,3 - 20 fC - DAC 256
# Pixel 3,3 - 20 fC - DAC 258
# Pixel 3,3 - 20 fC - DAC 260
# Pixel 3,3 - 20 fC - DAC 262
# Pixel 3,3 - 20 fC - DAC 264
# Pixel 3,3 - 20 fC - DAC 266
# Pixel 3,3 - 20 fC - DAC 268
# Pixel 3,3 - 20 fC - DAC 270
# Pixel 3,3 - 20 fC - DAC 272
# Pixel 3,3 - 20 fC - DAC 274
# Pixel 3,3 - 20 fC - DAC 276
# Pixel 3,3 - 20 fC - DAC 278
# Pixel 3,3 - 20 fC - DAC 280
# Pixel 3,3 - 20 fC - DAC 282
# Pixel 3,3 - 20 fC - DAC 284
# Pixel 3,3 - 20 fC - DAC 286
# Pixel 3,3 - 20 fC - DAC 288
# Pixel 3,3 - 20 fC - DAC 290
# Pixel 3,3 - 20 fC - DAC 292
# Pixel 3,3 - 20 fC - DAC 294
# Pixel 3,3 - 20 fC - DAC 296
# Pixel 3,3 - 20 fC - DAC 298
# Pixel 3,3 - 20 fC - DAC 300
# Pixel 3,3 - 20 fC - DAC 302
# Pixel 3,3 - 20 fC - DAC 304
# Pixel 3,3 - 20 fC - DAC 306
# Pixel 3,3 - 20 fC - DAC 308
# Pixel 3,3 - 20 fC - DAC 310
# Pixel 3,3 - 20 fC - DAC 312
# Pixel 3,3 - 20 fC - DAC 314
# Pixel 3,3 - 20 fC - DAC 316
# Pixel 3,3 - 20 fC - DAC 318
# Pixel 3,3 - 20 fC - DAC 320
# Pixel 3,3 - 20 fC - DAC 322
# Pixel 3,3 - 20 fC - DAC 324
# Pixel 3,3 - 20 fC - DAC 326
# Pixel 3,3 - 20 fC - DAC 328
# Pixel 3,3 - 20 fC - DAC 330
# Pixel 3,3 - 20 fC - DAC 332
# Pixel 3,3 - 20 fC - DAC 334
# Pixel 3,3 - 20 fC - DAC 336
# Pixel 3,3 - 20 fC - DAC 338
# Pixel 3,3 - 20 fC - DAC 340
# Pixel 3,3 - 20 fC - DAC 342
# Pixel 3,3 - 20 fC - DAC 344
# Pixel 3,3 - 20 fC - DAC 346
# Pixel 3,3 - 20 fC - DAC 348
# Pixel 3,3 - 20 fC - DAC 350
# Pixel 3,3 - 20 fC - DAC 352
# Pixel 3,3 - 20 fC - DAC 354
# Pixel 3,3 - 20 fC - DAC 356
# Pixel 3,3 - 20 fC - DAC 358
# Pixel 3,3 - 20 fC - DAC 360
# Pixel 3,3 - 20 fC - DAC 362
# Pixel 3,3 - 20 fC - DAC 364
# Pixel 3,3 - 20 fC - DAC 366
# Pixel 3,3 - 20 fC - DAC 368
# Pixel 3,3 - 20 fC - DAC 370
# Pixel 3,3 - 20 fC - DAC 372
# Pixel 3,3 - 20 fC - DAC 374
# Pixel 3,3 - 20 fC - DAC 376
# Pixel 3,3 - 20 fC - DAC 378
# Pixel 3,3 - 20 fC - DAC 380
# Pixel 3,3 - 20 fC - DAC 382
# Pixel 3,3 - 20 fC - DAC 384
# Pixel 3,3 - 20 fC - DAC 386
# Pixel 3,3 - 20 fC - DAC 388
# Pixel 3,3 - 20 fC - DAC 390
# Pixel 3,3 - 20 fC - DAC 392
# Pixel 3,3 - 20 fC - DAC 394
# Pixel 3,3 - 20 fC - DAC 396
# Pixel 3,3 - 20 fC - DAC 398
# Pixel 3,3 - 20 fC - DAC 400
# Pixel 3,3 - 20 fC - DAC 402
# Pixel 3,3 - 20 fC - DAC 404
# Pixel 3,3 - 20 fC - DAC 406
# Pixel 3,3 - 20 fC - DAC 408
# Pixel 3,3 - 25 fC - DAC 232
# Pixel 3,3 - 25 fC - DAC 234
# Pixel 3,3 - 25 fC - DAC 236
# Pixel 3,3 - 25 fC - DAC 238
# Pixel 3,3 - 25 fC - DAC 240
# Pixel 3,3 - 25 fC - DAC 242
# Pixel 3,3 - 25 fC - DAC 244
# Pixel 3,3 - 25 fC - DAC 246
# Pixel 3,3 - 25 fC - DAC 248
# Pixel 3,3 - 25 fC - DAC 250
# Pixel 3,3 - 25 fC - DAC 252
# Pixel 3,3 - 25 fC - DAC 254
# Pixel 3,3 - 25 fC - DAC 256
# Pixel 3,3 - 25 fC - DAC 258
# Pixel 3,3 - 25 fC - DAC 260
# Pixel 3,3 - 25 fC - DAC 262
# Pixel 3,3 - 25 fC - DAC 264
# Pixel 3,3 - 25 fC - DAC 266
# Pixel 3,3 - 25 fC - DAC 268
# Pixel 3,3 - 25 fC - DAC 270
# Pixel 3,3 - 25 fC - DAC 272
# Pixel 3,3 - 25 fC - DAC 274
# Pixel 3,3 - 25 fC - DAC 276
# Pixel 3,3 - 25 fC - DAC 278
# Pixel 3,3 - 25 fC - DAC 280
# Pixel 3,3 - 25 fC - DAC 282
# Pixel 3,3 - 25 fC - DAC 284
# Pixel 3,3 - 25 fC - DAC 286
# Pixel 3,3 - 25 fC - DAC 288
# Pixel 3,3 - 25 fC - DAC 290
# Pixel 3,3 - 25 fC - DAC 292
# Pixel 3,3 - 25 fC - DAC 294
# Pixel 3,3 - 25 fC - DAC 296
# Pixel 3,3 - 25 fC - DAC 298
# Pixel 3,3 - 25 fC - DAC 300
# Pixel 3,3 - 25 fC - DAC 302
# Pixel 3,3 - 25 fC - DAC 304
# Pixel 3,3 - 25 fC - DAC 306
# Pixel 3,3 - 25 fC - DAC 308
# Pixel 3,3 - 25 fC - DAC 310
# Pixel 3,3 - 25 fC - DAC 312
# Pixel 3,3 - 25 fC - DAC 314
# Pixel 3,3 - 25 fC - DAC 316
# Pixel 3,3 - 25 fC - DAC 318
# Pixel 3,3 - 25 fC - DAC 320
# Pixel 3,3 - 25 fC - DAC 322
# Pixel 3,3 - 25 fC - DAC 324
# Pixel 3,3 - 25 fC - DAC 326
# Pixel 3,3 - 25 fC - DAC 328
# Pixel 3,3 - 25 fC - DAC 330
# Pixel 3,3 - 25 fC - DAC 332
# Pixel 3,3 - 25 fC - DAC 334
# Pixel 3,3 - 25 fC - DAC 336
# Pixel 3,3 - 25 fC - DAC 338
# Pixel 3,3 - 25 fC - DAC 340
# Pixel 3,3 - 25 fC - DAC 342
# Pixel 3,3 - 25 fC - DAC 344
# Pixel 3,3 - 25 fC - DAC 346
# Pixel 3,3 - 25 fC - DAC 348
# Pixel 3,3 - 25 fC - DAC 350
# Pixel 3,3 - 25 fC - DAC 352
# Pixel 3,3 - 25 fC - DAC 354
# Pixel 3,3 - 25 fC - DAC 356
# Pixel 3,3 - 25 fC - DAC 358
# Pixel 3,3 - 25 fC - DAC 360
# Pixel 3,3 - 25 fC - DAC 362
# Pixel 3,3 - 25 fC - DAC 364
# Pixel 3,3 - 25 fC - DAC 366
# Pixel 3,3 - 25 fC - DAC 368
# Pixel 3,3 - 25 fC - DAC 370
# Pixel 3,3 - 25 fC - DAC 372
# Pixel 3,3 - 25 fC - DAC 374
# Pixel 3,3 - 25 fC - DAC 376
# Pixel 3,3 - 25 fC - DAC 378
# Pixel 3,3 - 25 fC - DAC 380
# Pixel 3,3 - 25 fC - DAC 382
# Pixel 3,3 - 25 fC - DAC 384
# Pixel 3,3 - 25 fC - DAC 386
# Pixel 3,3 - 25 fC - DAC 388
# Pixel 3,3 - 25 fC - DAC 390
# Pixel 3,3 - 25 fC - DAC 392
# Pixel 3,3 - 25 fC - DAC 394
# Pixel 3,3 - 25 fC - DAC 396
# Pixel 3,3 - 25 fC - DAC 398
# Pixel 3,3 - 25 fC - DAC 400
# Pixel 3,3 - 25 fC - DAC 402
# Pixel 3,3 - 25 fC - DAC 404
# Pixel 3,3 - 25 fC - DAC 406
# Pixel 3,3 - 25 fC - DAC 408
# Pixel 3,3 - 25 fC - DAC 410
# Pixel 3,3 - 25 fC - DAC 412
# Pixel 3,3 - 25 fC - DAC 414
# Pixel 3,3 - 25 fC - DAC 416
# Pixel 3,3 - 25 fC - DAC 418
# Pixel 3,3 - 25 fC - DAC 420
# Pixel 3,3 - 25 fC - DAC 422
# Pixel 3,3 - 25 fC - DAC 424
# Pixel 3,3 - 25 fC - DAC 426
# Pixel 3,3 - 25 fC - DAC 428
# Pixel 3,3 - 25 fC - DAC 430
# Pixel 3,3 - 25 fC - DAC 432
# Pixel 3,3 - 25 fC - DAC 434
# Pixel 3,3 - 25 fC - DAC 436
# Pixel 3,3 - 25 fC - DAC 438
# Pixel 3,3 - 25 fC - DAC 440
# Pixel 3,3 - 25 fC - DAC 442
# Pixel 3,3 - 25 fC - DAC 444
# Pixel 3,3 - 25 fC - DAC 446
# Pixel 3,3 - 25 fC - DAC 448
# Pixel 3,3 - 25 fC - DAC 450
# Pixel 3,3 - 25 fC - DAC 452
# Pixel 3,3 - 25 fC - DAC 454
# Pixel 3,3 - 30 fC - DAC 232
# Pixel 3,3 - 30 fC - DAC 234
# Pixel 3,3 - 30 fC - DAC 236
# Pixel 3,3 - 30 fC - DAC 238
# Pixel 3,3 - 30 fC - DAC 240
# Pixel 3,3 - 30 fC - DAC 242
# Pixel 3,3 - 30 fC - DAC 244
# Pixel 3,3 - 30 fC - DAC 246
# Pixel 3,3 - 30 fC - DAC 248
# Pixel 3,3 - 30 fC - DAC 250
# Pixel 3,3 - 30 fC - DAC 252
# Pixel 3,3 - 30 fC - DAC 254
# Pixel 3,3 - 30 fC - DAC 256
# Pixel 3,3 - 30 fC - DAC 258
# Pixel 3,3 - 30 fC - DAC 260
# Pixel 3,3 - 30 fC - DAC 262
# Pixel 3,3 - 30 fC - DAC 264
# Pixel 3,3 - 30 fC - DAC 266
# Pixel 3,3 - 30 fC - DAC 268
# Pixel 3,3 - 30 fC - DAC 270
# Pixel 3,3 - 30 fC - DAC 272
# Pixel 3,3 - 30 fC - DAC 274
# Pixel 3,3 - 30 fC - DAC 276
# Pixel 3,3 - 30 fC - DAC 278
# Pixel 3,3 - 30 fC - DAC 280
# Pixel 3,3 - 30 fC - DAC 282
# Pixel 3,3 - 30 fC - DAC 284
# Pixel 3,3 - 30 fC - DAC 286
# Pixel 3,3 - 30 fC - DAC 288
# Pixel 3,3 - 30 fC - DAC 290
# Pixel 3,3 - 30 fC - DAC 292
# Pixel 3,3 - 30 fC - DAC 294
# Pixel 3,3 - 30 fC - DAC 296
# Pixel 3,3 - 30 fC - DAC 298
# Pixel 3,3 - 30 fC - DAC 300
# Pixel 3,3 - 30 fC - DAC 302
# Pixel 3,3 - 30 fC - DAC 304
# Pixel 3,3 - 30 fC - DAC 306
# Pixel 3,3 - 30 fC - DAC 308
# Pixel 3,3 - 30 fC - DAC 310
# Pixel 3,3 - 30 fC - DAC 312
# Pixel 3,3 - 30 fC - DAC 314
# Pixel 3,3 - 30 fC - DAC 316
# Pixel 3,3 - 30 fC - DAC 318
# Pixel 3,3 - 30 fC - DAC 320
# Pixel 3,3 - 30 fC - DAC 322
# Pixel 3,3 - 30 fC - DAC 324
# Pixel 3,3 - 30 fC - DAC 326
# Pixel 3,3 - 30 fC - DAC 328
# Pixel 3,3 - 30 fC - DAC 330
# Pixel 3,3 - 30 fC - DAC 332
# Pixel 3,3 - 30 fC - DAC 334
# Pixel 3,3 - 30 fC - DAC 336
# Pixel 3,3 - 30 fC - DAC 338
# Pixel 3,3 - 30 fC - DAC 340
# Pixel 3,3 - 30 fC - DAC 342
# Pixel 3,3 - 30 fC - DAC 344
# Pixel 3,3 - 30 fC - DAC 346
# Pixel 3,3 - 30 fC - DAC 348
# Pixel 3,3 - 30 fC - DAC 350
# Pixel 3,3 - 30 fC - DAC 352
# Pixel 3,3 - 30 fC - DAC 354
# Pixel 3,3 - 30 fC - DAC 356
# Pixel 3,3 - 30 fC - DAC 358
# Pixel 3,3 - 30 fC - DAC 360
# Pixel 3,3 - 30 fC - DAC 362
# Pixel 3,3 - 30 fC - DAC 364
# Pixel 3,3 - 30 fC - DAC 366
# Pixel 3,3 - 30 fC - DAC 368
# Pixel 3,3 - 30 fC - DAC 370
# Pixel 3,3 - 30 fC - DAC 372
# Pixel 3,3 - 30 fC - DAC 374
# Pixel 3,3 - 30 fC - DAC 376
# Pixel 3,3 - 30 fC - DAC 378
# Pixel 3,3 - 30 fC - DAC 380
# Pixel 3,3 - 30 fC - DAC 382
# Pixel 3,3 - 30 fC - DAC 384
# Pixel 3,3 - 30 fC - DAC 386
# Pixel 3,3 - 30 fC - DAC 388
# Pixel 3,3 - 30 fC - DAC 390
# Pixel 3,3 - 30 fC - DAC 392
# Pixel 3,3 - 30 fC - DAC 394
# Pixel 3,3 - 30 fC - DAC 396
# Pixel 3,3 - 30 fC - DAC 398
# Pixel 3,3 - 30 fC - DAC 400
# Pixel 3,3 - 30 fC - DAC 402
# Pixel 3,3 - 30 fC - DAC 404
# Pixel 3,3 - 30 fC - DAC 406
# Pixel 3,3 - 30 fC - DAC 408
# Pixel 3,3 - 30 fC - DAC 410
# Pixel 3,3 - 30 fC - DAC 412
# Pixel 3,3 - 30 fC - DAC 414
# Pixel 3,3 - 30 fC - DAC 416
# Pixel 3,3 - 30 fC - DAC 418
# Pixel 3,3 - 30 fC - DAC 420
# Pixel 3,3 - 30 fC - DAC 422
# Pixel 3,3 - 30 fC - DAC 424
# Pixel 3,3 - 30 fC - DAC 426
# Pixel 3,3 - 30 fC - DAC 428
# Pixel 3,3 - 30 fC - DAC 430
# Pixel 3,3 - 30 fC - DAC 432
# Pixel 3,3 - 30 fC - DAC 434
# Pixel 3,3 - 30 fC - DAC 436
# Pixel 3,3 - 30 fC - DAC 438
# Pixel 3,3 - 30 fC - DAC 440
# Pixel 3,3 - 30 fC - DAC 442
# Pixel 3,3 - 30 fC - DAC 444
# Pixel 3,3 - 30 fC - DAC 446
# Pixel 3,3 - 30 fC - DAC 448
# Pixel 3,3 - 30 fC - DAC 450
# Pixel 3,3 - 30 fC - DAC 452
# Pixel 3,3 - 30 fC - DAC 454
# Pixel 3,3 - 30 fC - DAC 456
# Pixel 3,3 - 30 fC - DAC 458
# Pixel 3,3 - 30 fC - DAC 460
# Pixel 3,3 - 30 fC - DAC 462
# Pixel 3,3 - 30 fC - DAC 464
# Pixel 3,3 - 30 fC - DAC 466
# Pixel 3,3 - 30 fC - DAC 468
# Pixel 3,3 - 30 fC - DAC 470
# Pixel 3,3 - 30 fC - DAC 472
# Pixel 3,3 - 30 fC - DAC 474
# Pixel 3,3 - 30 fC - DAC 476
# Pixel 3,3 - 30 fC - DAC 478
# Pixel 3,3 - 30 fC - DAC 480
# Pixel 3,3 - 30 fC - DAC 482
# Pixel 3,3 - 30 fC - DAC 484
# Pixel 3,3 - 30 fC - DAC 486
# Pixel 3,3 - 30 fC - DAC 488
# Pixel 3,3 - 30 fC - DAC 490
# Pixel 3,3 - 30 fC - DAC 492
# Pixel 3,3 - 30 fC - DAC 494

# %%
BL_map_toplot = np.array([[BL_map_THCal[(row,col)][15][232] for col in col_list] for row in row_list])
MW_map_toplot = np.array([[NW_map_THCal[(row,col)][15][232] for col in col_list] for row in row_list])

fig = plt.figure(dpi=200, figsize=(10,10))
gs = fig.add_gridspec(1,2)

ax0 = fig.add_subplot(gs[0,0])
ax0.set_title("BL (DAC LSB), "+"Bare Chip 01E2 #52", size=8)
img0 = ax0.imshow(BL_map_toplot, interpolation='none')
ax0.set_aspect("equal")
ax0.invert_xaxis()
ax0.invert_yaxis()
plt.xticks(range(16), range(16), rotation="vertical")
plt.yticks(range(16), range(16))
divider = make_axes_locatable(ax0)
cax = divider.append_axes('right', size="5%", pad=0.05)
fig.colorbar(img0, cax=cax, orientation="vertical")

ax1 = fig.add_subplot(gs[0,1])
ax1.set_title("NW (DAC LSB), "+"Bare Chip 01E2 #52", size=8)
img1 = ax1.imshow(MW_map_toplot, interpolation='none')
ax1.set_aspect("equal")
ax1.invert_xaxis()
ax1.invert_yaxis()
plt.xticks(range(16), range(16), rotation="vertical")
plt.yticks(range(16), range(16))
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size="5%", pad=0.05)
fig.colorbar(img1, cax=cax, orientation="vertical")

for x in range(16):
    for y in range(16):
        # if(BL_map_THCal.T[x,y]==0): continue
        ax0.text(x,y,f"{BL_map_toplot.T[x,y]:.0f}", c="white", size=5, rotation=45, fontweight="bold", ha="center", va="center")
        ax1.text(x,y,f"{MW_map_toplot.T[x,y]:.0f}", c="white", size=5, rotation=45, fontweight="bold", ha="center", va="center")
# plt.savefig(fig_path+"BL_NW_"+chip_figname+".png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 34
#      31 for x in range(16):
#      32     for y in range(16):
#      33         # if(BL_map_THCal.T[x,y]==0): continue
# ---> 34         ax0.text(x,y,f"{BL_map_toplot.T[x,y]:.0f}", c="white", size=5, rotation=45, fontweight="bold", ha="center", va="center")
#      35         ax1.text(x,y,f"{MW_map_toplot.T[x,y]:.0f}", c="white", size=5, rotation=45, fontweight="bold", ha="center", va="center")
#      36 # plt.savefig(fig_path+"BL_NW_"+chip_figname+".png")
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %% [markdown]
# ## S-Curve Plots

# %%
def turning_point(key_array, array):
    return np.argmax(np.where(key_array>2000, array, 0))

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        ax0.axvline(BL_map_THCal[(row,col)][15][232], color='k', lw=0.7, label=f"THCal BL = {int(BL_map_THCal[(row,col)][15][232])}")
        ax0.axvline(BL_map_THCal[(row,col)][15][232]+NW_map_THCal[(row,col)][15][232], color='k',ls="--", lw=0.8, label=f"THCal NW = $\pm${int(NW_map_THCal[(row,col)][15][232])}")
        ax0.axvline(BL_map_THCal[(row,col)][15][232]-NW_map_THCal[(row,col)][15][232], color='k',ls="--", lw=0.8)
        ax0.axvline(thresholds[QInj][15], color='k', lw=0.7)
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            ax0.axvline(thresholds[QInj][tp_idx], color='k', lw=0.7)
            ax0.plot(thresholds[QInj], hit_counts[(row,col)][QInj].values(), '.-', label=f"{QInj} fC", lw=0.7, markersize=3)
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("Data Counts [decimal]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        # ax0.plot(thresholds[idx_min], np.array(list(hitmap_full_Scurve[row][col][QInj].values()))[idx_min], 'ro')
        # ax0.plot(thresholds[idx_max], np.array(list(hitmap_full_Scurve[row][col][QInj].values()))[idx_max], 'go')
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/simple_scurve.pdf")
plt.show()

# %%
# https://nbviewer.org/github/demotu/BMC/blob/master/notebooks/CurveFitting.ipynb
# https://tomholderness.wordpress.com/2013/01/10/confidence_intervals/
# https://stackoverflow.com/questions/27164114/show-confidence-limits-and-prediction-limits-in-scatter-plot

fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        ax0.axhline(BL_map_THCal[(row,col)][15][232], color='k', lw=0.8, label=f"THCal BL = {int(BL_map_THCal[(row,col)][15][232])} DAC LSB")
        ax0.axhline(BL_map_THCal[(row,col)][15][232]+NW_map_THCal[(row,col)][15][232], color='k',ls="--", lw=0.8, label=f"THCal NW = $\pm${int(NW_map_THCal[(row,col)][15][232])} DAC LSB")
        ax0.axhline(BL_map_THCal[(row,col)][15][232]-NW_map_THCal[(row,col)][15][232], color='k',ls="--", lw=0.8)
        X = []
        Y = []
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            ax0.plot(QInj, thresholds[QInj][tp_idx], 'ro')
            X.append(QInj)
            Y.append(thresholds[QInj][tp_idx])
        X = np.array(X)
        Y = np.array(Y)
        (m, b), cov = np.polyfit(X, Y, 1, cov = True)
        n = Y.size
        Yfit = np.polyval((m,b), X)
        errorbars = np.sqrt(np.diag(cov))
        x_range = np.linspace(0, 35, 100)
        y_est = b + m*x_range
        resid = Y - Yfit
        s_err = np.sqrt(np.sum(resid**2)/(n - 2))
        t = stats.t.ppf(0.95, n - 2)
        ci = t * s_err * np.sqrt(    1/n + (X - np.mean(X))**2/np.sum((X-np.mean(X))**2)) # confidence interval
        pi = t * s_err * np.sqrt(1 + 1/n + (X - np.mean(X))**2/np.sum((X-np.mean(X))**2)) # prediction interval
        # cip= t * s_err * np.sqrt(    1/n + (X - np.mean(X))**2/(np.sum((X)**2)-n*np.sum((np.mean(X))**2)))
        ci2= t * s_err * np.sqrt(    1/n + (x_range - np.mean(X))**2/(np.sum((X)**2)-n*np.sum((np.mean(X))**2)))
        
        ax0.plot(x_range, y_est, 'b-', lw=-.8, label=f"DAC_TH = ({m:.3f}$\pm${errorbars[0]:.3f} [1/fC])$\cdot$Q + ({b:.3f}$\pm${errorbars[1]:.3f})")
        plt.fill_between(x_range, y_est+ci2, y_est-ci2, color='b',alpha=0.2, label="95% Confidence Interval on Linear Fit")
        ax0.set_xlabel("Charge Injected [fC]")
        ax0.set_ylabel("DAC Threshold [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("figures/q_vs_dac_scurve.pdf")
plt.savefig("figures/q_vs_dac_scurve.png")
plt.show()

# %% [markdown]
# ## TOA TOT CAL plots vs DAC

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])

        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")

            p = np.polyfit(thresholds[QInj][15:tp_idx-2], np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-2], 3)
            x_range = np.linspace(248, thresholds[QInj][15:tp_idx-2], 100)
            Yest = np.polyval(p, x_range)
            ax0.plot(x_range, Yest, 'k-', lw=0.7)

        ax0.axvline(BL_map_THCal[(row,col)][15][232], color='k', lw=0.7, label=f"THCal BL = {int(BL_map_THCal[(row,col)][15][232])}")
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("TOA Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")

        
plt.tight_layout()
# plt.savefig("figures/toa_mean_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("TOA Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/toa_mean_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        X = []
        Y = []
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(TOA_std[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(TOA_std[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
            X.append(QInj)
            Y.append(thresholds[QInj][tp_idx])
        X = np.array(X)
        Y = np.array(Y)
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("TOA Std [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/ta_std_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        X = []
        Y = []
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(CAL_mean[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(CAL_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
            X.append(QInj)
            Y.append(thresholds[QInj][tp_idx])
        X = np.array(X)
        Y = np.array(Y)
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("CAL Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/cal_mean_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        X = []
        Y = []
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(CAL_std[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(CAL_std[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
            X.append(QInj)
            Y.append(thresholds[QInj][tp_idx])
        X = np.array(X)
        Y = np.array(Y)
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("CAL Std [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/cal_std_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        X = []
        Y = []
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(TOT_mean[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(TOT_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
            X.append(QInj)
            Y.append(thresholds[QInj][tp_idx])
        X = np.array(X)
        Y = np.array(Y)
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("TOT Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/tot_mean_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        X = []
        Y = []
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(thresholds[QInj][15:tp_idx-2], np.array(list(TOT_std[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(thresholds[QInj][15:tp_idx-0], np.array(list(TOT_std[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
            X.append(QInj)
            Y.append(thresholds[QInj][tp_idx])
        X = np.array(X)
        Y = np.array(Y)
        ax0.set_xlabel("DAC Value [LSB]")
        ax0.set_ylabel("TOT Std [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/tot_std_scurve.pdf")
plt.show()

# %% [markdown]
# # TOA vs TOT

# %%
fig = plt.figure(dpi=200, figsize=(8,4))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        for QInj in QInjEns:
            tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
            if(QInj==5):
                ax0.plot(np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-2], np.array(list(TOT_mean[(row,col)][QInj].values()))[15:tp_idx-2], '.-', label=f"{QInj} fC")
            else:
                ax0.plot(np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-0], np.array(list(TOT_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
        ax0.set_xlabel("TOA Mean [LSB]")
        ax0.set_ylabel("TOT Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/toa_mean_vs_tot_mean_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=100, figsize=(8,8))
gs = fig.add_gridspec(1,1)
row = 3
col = 3
QInj = 30
ax0 = fig.add_subplot(gs[0,0])
tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
print(tp_idx)
ax0.plot(np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-0], np.array(list(TOT_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
ax0.plot(toa_30fc, tot_30fc, '.')
p, cov = np.polyfit(tot_30fc, toa_30fc, 3, cov = True)
n = tot_30fc.size
x_range = np.linspace(10, 80, 100)
Yest = np.polyval(p, x_range)
ax0.plot(Yest, x_range, 'k-', label=f'TOA = {p[-1]:.3f} + {p[-2]:.3f}.TOT + {p[-3]:.3f}.TOT**2 + {p[-4]:.3f}.TOT**3')
        
ax0.set_xlabel("TOA Mean [LSB]")
ax0.set_ylabel("TOT Mean [LSB]")
plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
plt.legend(loc="upper left")
plt.tight_layout()
# plt.savefig("figures/toa_vs_tot_scurve.pdf")
plt.show()
# Out:
# 125

# %%
fig = plt.figure(dpi=100, figsize=(8,8))
gs = fig.add_gridspec(1,1)
row = 3
col = 3
QInj = 30
ax0 = fig.add_subplot(gs[0,0])
code_conversion = 3.125/np.array(cal_30fc)
ax0.plot(code_conversion*toa_30fc, code_conversion*tot_30fc, '.')
p, cov = np.polyfit(code_conversion*tot_30fc, code_conversion*toa_30fc, 3, cov = True)
n = tot_30fc.size
x_range = np.linspace(0.3, 1.5, 100)
Yest = np.polyval(p, x_range)
ax0.plot(Yest, x_range, 'k-', label=f'TOA = {p[-1]:.3f} + {p[-2]:.3f}.TOT + {p[-3]:.3f}.TOT**2 + {p[-4]:.3f}.TOT**3')
ax0.set_xlabel("TOA [ns]")
ax0.set_ylabel("TOT [ns]")
plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("figures/toa_vs_tot_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=100, figsize=(8,8))
gs = fig.add_gridspec(1,1)
row = 3
col = 3
QInj = 30
ax = fig.add_subplot(gs[0,0])
Y_resid = 1000*(code_conversion*toa_30fc - np.polyval(p, code_conversion*tot_30fc))
hist_1 = hist.Hist(
    hist.axis.Regular(
        8, -50, 50, name="TOA", label="TOA Corrected [ps]", underflow=False, overflow=False
    )
).fill(Y_resid)
hist_1.project("TOA").plot1d(ax=ax, lw=1, histtype="fill")
ax.set_xticks(ax.get_xticks(),ax.get_xticklabels())
plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
plt.tight_layout()
# plt.savefig("figures/toa_vs_tot_scurve.pdf")
plt.show()

# %%
Y_resid = 1000*(code_conversion*toa_30fc - np.polyval(p, code_conversion*tot_30fc))
hist_1 = hist.Hist(
    hist.axis.Regular(
        8, -50, 50, name="TOA", label="TOA Corrected [ps]", underflow=False, overflow=False
    )
).fill(Y_resid)
fig = plt.figure(figsize=(10, 8))
# hist_1.plot_pull("constant*np.exp(-(x-mean)**2. / (2*sigma**2))",
#                 fit_fmt="")
# hist_1.plot_pull("gaus",
#                 fit_fmt=r"{name} = {value:.3g} $\pm$ {error:.3g}")
main_ax_artists, sublot_ax_arists = hist_1.plot_pull(
    "normal",
    fit_fmt=r"{name} = {value:.3g} $\pm$ {error:.3g}",
    eb_ecolor="steelblue",
    eb_mfc="steelblue",
    eb_mec="steelblue",
    eb_fmt="o",
    eb_ms=6,
    eb_capsize=1,
    eb_capthick=2,
    eb_alpha=0.8,
    fp_c="hotpink",
    fp_ls="-",
    fp_lw=2,
    fp_alpha=0.8,
    bar_fc="royalblue",
    pp_num=3,
    pp_fc="royalblue",
    pp_alpha=0.618,
    pp_ec=None,
    ub_alpha=0.2,
)

# %%
fig = plt.figure(dpi=100, figsize=(6,6))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        QInj = 30
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
        ax0.plot(np.array(list(TOA_mean[(row,col)][QInj].values()))[15:tp_idx-0], np.array(list(CAL_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
        ax0.plot(toa_30fc, cal_30fc, '.')
        ax0.set_xlabel("TOA Mean [LSB]")
        ax0.set_ylabel("CAL Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/toa_vs_cal_scurve.pdf")
plt.show()

# %%
fig = plt.figure(dpi=100, figsize=(6,6))
gs = fig.add_gridspec(len(scan_list),len(scan_list))
u_cl = np.sort(np.unique(col_list))
u_rl = np.sort(np.unique(row_list))
for ri,row in enumerate(u_rl):
    for ci,col in enumerate(u_cl):
        QInj = 30
        ax0 = fig.add_subplot(gs[len(u_rl)-ri-1,len(u_cl)-ci-1])
        tp_idx = turning_point(np.array(list(hit_counts[(row,col)][QInj].values())), thresholds[QInj])
        ax0.plot(np.array(list(TOT_mean[(row,col)][QInj].values()))[15:tp_idx-0], np.array(list(CAL_mean[(row,col)][QInj].values()))[15:tp_idx-0], '.-', label=f"{QInj} fC")
        ax0.plot(tot_30fc, cal_30fc, '.')
        ax0.set_xlabel("TOT Mean [LSB]")
        ax0.set_ylabel("CAL Mean [LSB]")
        plt.title(f"Bare Chip 01E2 #52, Pixel ({row},{col}), Qinj S-Curve, PA Low Bias Current Mode")
        plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("figures/tot_vs_cal_scurve.pdf")
plt.show()
