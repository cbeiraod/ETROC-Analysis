# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mplhep as hep
hep.style.use("CMS")

# %%
folder_path = "/Users/murtazas-local/Downloads/ws_testing_ 2/ws_testing_4/"
sample_name = "rawdataWS_chipname_NA_2024-05-05_00-44_4.csv"

# %%
df = pd.read_csv(folder_path+sample_name)

# %%
df
# Out:
#       Time Index  Data Address  Data       Raw Data  pointer  Dout_S1
# 0              0           988  4791  1001010110111        0       37  \
# 1              1           860  4811  1001011001011        0       37
# 2              2           732  4788  1001010110100        0       37
# 3              3           604  4632  1001000011000        0       36
# 4              4           476  4963  1001101100011        0       38
# ...          ...           ...   ...            ...      ...      ...
# 1019        1019           603  4632  1001000011000        0       36
# 1020        1020           475  4963  1001101100011        0       38
# 1021        1021           347  4788  1001010110100        0       37
# 1022        1022           219  4489  1000110001001        0       35
# 1023        1023            91  4635  1001000011011        0       36
#
#       Dout_S2    Dout  Channel   Time [ns]
# 0          33  34.195        8    0.000000
# 1          33  34.195        7    0.390625
# 2          30  34.450        6    0.781250
# 3          16  34.640        5    1.171875
# 4          43  34.345        4    1.562500
# ...       ...     ...      ...         ...
# 1019       16  34.640        5  398.046875
# 1020       43  34.345        4  398.437500
# 1021       30  34.450        3  398.828125
# 1022        7  34.405        2  399.218750
# 1023       19  34.385        1  399.609375
#
# [1024 rows x 10 columns]

# %%
plot_title = r'4 GeV $e^{-}$ at DESY TB | Waveform Sampler on Pixel (0,14)'
fig, ax = plt.subplots(figsize=(16, 7))
ax.set_title(plot_title, loc="right", size=16)
hep.cms.text(loc=0, ax=ax, text="ETL ETROC Test Beam", fontsize=18)
ax.plot(df["Time [ns]"], df["Dout"],"-", color="#e7298a")
ax.xaxis.label.set_fontsize(25)
ax.yaxis.label.set_fontsize(25)
ax.set_ylabel("Sampled Preamp Waveform [mV]")
ax.set_xlabel("Sample Time [ns]")
plt.tight_layout()
